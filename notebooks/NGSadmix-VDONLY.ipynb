# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/ngsadmix/R")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
dir()
# Out:
#  [1] "all44_2.txt"                        "all44_3.txt"
#  [3] "all44_4.txt"                        "all44_5.txt"
#  [5] "all44_6.txt"                        "all44_7.txt"
#  [7] "NGSAdmixtest-combined-14022018.pdf" "vd_2.txt"
#  [9] "vd_3.txt"                           "vd_4.txt"
# [11] "vd_5.txt"                           "vd_6.txt"
# [13] "vd_7.txt"                           "vj_2.txt"
# [15] "vj_3.txt"                           "vj_4.txt"
# [17] "vj_5.txt"                           "vj_6.txt"
# [19] "vj_7.txt"

# %%
admix2<-t(as.matrix(read.table("vd_2.txt")))
barplot(admix2, col=c("red2", "lightpink"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix3 <-t(as.matrix(read.table("vd_3.txt")))
barplot(admix3, col=c("darkviolet", "red2", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix4 <-t(as.matrix(read.table("vd_4.txt")))
barplot(admix4, col=c("lightpink", "darkviolet", "orange", "red2"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix5 <-t(as.matrix(read.table("vd_5.txt")))
barplot(admix5, col=c("darkviolet","red2", "black", "lightpink", "orange"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix6 <-t(as.matrix(read.table("vd_6.txt")))
barplot(admix6, col=c("white", "red2","black", "orange", "darkviolet", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix7 <-t(as.matrix(read.table("vd_7.txt")))
barplot(admix7, col=c("white", "darkviolet", "red2","green", "orange", "black", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pdf(file = "NGSAdmixtest-VDONLY-14022018.pdf", height=30, width= 20)
par(mfrow=c(6,1)) 
barplot(admix2, col=c("red2", "lightpink"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix3, col=c("darkviolet", "red2", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix4, col=c("lightpink", "darkviolet", "orange", "red2"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix5, col=c("darkviolet","red2", "black", "lightpink", "orange"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix6, col=c("white", "red2","black", "orange", "darkviolet", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix7, col=c("white", "darkviolet", "red2","green", "orange", "black", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
dev.off()
# Out:
# png
#   2

# %%
dev.off()
# Out:
# null device
#           1
