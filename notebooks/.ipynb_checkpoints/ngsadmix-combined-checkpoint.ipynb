# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/ngsadmix/R")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
dir()
# Out:
# [1] "all44_2.txt" "all44_3.txt" "all44_4.txt" "all44_5.txt" "all44_6.txt"
# [6] "all44_7.txt"

# %%
admix2<-t(as.matrix(read.table("all44_2.txt")))
barplot(admix2, col=c("red2", "blue3"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix3 <-t(as.matrix(read.table("all44_3.txt")))
barplot(admix3, col=c("red2", "blue3", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix4 <-t(as.matrix(read.table("all44_4.txt")))
barplot(admix4, col=c("red2", "black", "lightpink", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix5 <-t(as.matrix(read.table("all44_5.txt")))
barplot(admix5, col=c("blue3", "red2", "lightpink", "black", "cyan"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix6 <-t(as.matrix(read.table("all44_6.txt")))
barplot(admix6, col=c("red2", "cyan", "lightpink", "blue3", "black", "white"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix7 <-t(as.matrix(read.table("all44_7.txt")))
barplot(admix7, col=c("cyan", "gray", "lightpink", "blue3", "black", "red2", "white"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pdf(file = "NGSAdmixtest-combined-14022018.pdf", height=30, width= 20)
par(mfrow=c(6,1)) 
barplot(admix2, col=c("red2", "blue3"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix3, col=c("red2", "blue3", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix4, col=c("red2", "black", "lightpink", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix5, col=c("blue3", "red2", "lightpink", "black", "cyan"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix6, col=c("red2", "cyan", "lightpink", "blue3", "black", "white"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix7, col=c("cyan", "gray", "lightpink", "blue3", "black", "red2", "white"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
dev.off()
# Out:
# png
#   2

# %%
dev.off()
# Out:
# null device
#           1
