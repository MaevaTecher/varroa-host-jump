# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/R")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
library(ade4)
library(ape)
library(adegenet)
library(vcfR)
# Out:
# Warning message:
# “replacing previous import ‘Matrix::expm’ by ‘expm::expm’ when loading ‘spdep’”
#    /// adegenet 2.1.0 is loaded ////////////
#
#    > overview: '?adegenet'
#    > tutorials/doc/questions: 'adegenetWeb()'
#    > bug reports/feature requests: adegenetIssues()
#
#
#
#    *****       ***   vcfR   ***       *****
#    This is vcfR 1.5.0
#      browseVignettes('vcfR') # Documentation
#      citation('vcfR') # Citation
#    *****       *****      *****       *****

# %%
##import vcf file
varroavcf <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/primitives-sort.vcf.gz")
# Out:
# Meta line 1490 read in.
# All meta lines processed.
# Character matrix gt created.
# Character matrix gt rows: 3016981
# Character matrix gt cols: 53
# skip: 0
# nrows: 3016981
# row_num: 0
#
# Processed variant: 3016981
# All variants processed

# %% [markdown]
# Import every vcf chromosome

# %%
#import each chromosome
chrom1 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom1-sort.vcf.gz")
chrom2 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom2-sort.vcf.gz")
chrom3 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom3-sort.vcf.gz")
chrom4 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom4-sort.vcf.gz")
chrom5 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom5-sort.vcf.gz")
chrom6 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom6-sort.vcf.gz")
chrom7 <- read.vcfR("/work/MikheyevU/Maeva/varroa-jump/data/var/subset/chromosome/sort/chrom7-sort.vcf.gz")
# Out:
# Meta line 1491 read in.
# All meta lines processed.
# Character matrix gt created.
# Character matrix gt rows: 635891
# Character matrix gt cols: 53
# skip: 0
# nrows: 635891
# row_num: 0
#
# Processed variant: 635891
# All variants processed
# Meta line 1491 read in.
# All meta lines processed.
# Character matrix gt created.
# Character matrix gt rows: 499260
# Character matrix gt cols: 53
# skip: 0
# nrows: 499260
# row_num: 0
#
# Processed variant: 499260
# All variants processed
# Meta line 1491 read in.
# All meta lines processed.
# Character matrix gt created.
# Character matrix gt rows: 462525
# Character matrix gt cols: 53
# skip: 0
# nrows: 462525
# row_num: 0
#
# Processed variant: 462525
# All variants processed
# Meta line 1491 read in.
# All meta lines processed.
# Character matrix gt created.
# Character matrix gt rows: 425618
# Character matrix gt cols: 53
# skip: 0
# nrows: 425618
# row_num: 0
#
# Processed variant: 425618
# All variants processed
# ...

# %%
pop.data <- read.table("/work/MikheyevU/Maeva/varroa-jump/data/R/popvarroaR.txt", sep = "\t", header = TRUE)
summary(pop.data)
# Out:
#        ID        POP
#  VD149  : 1   VdAc : 9
#  VD150_2: 1   VdAm :10
#  VD153_2: 1   VjAc :11
#  VD159_1: 1   VjAm : 8
#  VD212  : 1   VspAc: 6
#  VD474_1: 1
#  (Other):38

# %%
colnames(varroavcf@gt)[-1] == pop.data$ID
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [31] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE

# %%
#converting database to a genlight object
glall <- vcfR2genlight(varroavcf)

# %%
gl1 <- vcfR2genlight(chrom1)
gl2 <- vcfR2genlight(chrom2)
gl3 <- vcfR2genlight(chrom3)
gl4 <- vcfR2genlight(chrom4)
gl5 <- vcfR2genlight(chrom5)
gl6 <- vcfR2genlight(chrom6)
gl7 <- vcfR2genlight(chrom7)

# %%
ploidy(glall)
# Out:
#      VD212      VD149    VD475_1    VD642_1    VD651_1    VD577_1    VD654_1
#          2          2          2          2          2          2          2
#    VD658_2    VD657_1    VD676_2    VD153_2    VD159_1    VD150_2    VD474_1
#          2          2          2          2          2          2          2
#    VD639_1    VD625_2    VD622_1    VD641_1    VD646_1    VJ333_1    VJ341_1
#          2          2          2          2          2          2          2
#    VJ347_1    VJ363_1    VJ325_1    VJ565_2    VJ950_1    VJ854_1 VJ853_4_V2
#          2          2          2          2          2          2          2
#    VJ983_1    VJ856_1    VJ857_2 VJ852_3_V2      VJ847    VJ953_2    VJ952_1
#          2          2          2          2          2          2          2
# VJ956_4_V2    VJ955_1    VJ954_2      VJ028      VD780    VD787_2 VD788_1_V2
#          2          2          2          2          2          2          2
#    VD788_2    VD789_1
#          2          2

# %%
glall$pop <- pop.data$POP
gl1$pop <- pop.data$POP
gl2$pop <- pop.data$POP
gl3$pop <- pop.data$POP
gl4$pop <- pop.data$POP
gl5$pop <- pop.data$POP
gl6$pop <- pop.data$POP
gl7$pop <- pop.data$POP

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom1.pdf", height=6, width= 15)
glPlot(gl1, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom2.pdf", height=6, width= 15)
glPlot(gl2, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom3.pdf", height=6, width= 15)
glPlot(gl3, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom4.pdf", height=6, width= 15)
glPlot(gl4, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom5.pdf", height=6, width= 15)
glPlot(gl5, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom6.pdf", height=6, width= 15)
glPlot(gl6, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom7.pdf", height=6, width= 15)
glPlot(gl7, col=c("yellow", "orange", "red2"), bg="white", leg=FALSE) 
dev.off()

# %%
## perform PCA
pcaall <- glPca(glall, nf=5)

# %%
pdf(file = "/work/MikheyevU/Maeva/varroa-jump/data/R/chrom72.pdf", height=6, width= 15)
plot(gl7, col=c("yellow", "orange", "red2")) 
dev.off()

# %% [markdown]
# Following the conversion example of http://wurmlab.github.io/genomicscourse/2017/practicals/population_genetics/popgen
# Transform the vcf file into a matrix snp with position
# `bcftools query /work/MikheyevU/Maeva/varroa-jump/data/var/filtered.vcf.gz -f '%CHROM\t%POS[\t%GT]\n' > snp_matrix.txt`
#
# I sorted the samples using bcftools view and the option -S with implementing the list
# `bcftools view -Oz -S sortsiteyear.txt filtered.vcf.gz > filtered-sort.vcf.gz`

# %%
library(OutFLANK)
library(ggrepel) # for text labels
library(pcadapt)
library(data.table)
# Out:
# Loading required package: ggplot2
# Error in library(pcadapt): there is no package called ‘pcadapt’
# Traceback:
#
# 1. library(pcadapt)
# 2. stop(txt, domain = NA)

# %%
install.packages("pcaadapt")
# Out:
# Installing package into ‘/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2’
# (as ‘lib’ is unspecified)
# Warning message:
# “package ‘pcaadapt’ is not available (for R version 3.3.2)”

# %% [markdown]
# Making bin
# download size chromosome
# /apps/unit/MikheyevU/sasha/BEDTools-Version-2.16.2/bin/bedtools makewindows -g varroa.clean.sizes -w 100000 > windows.bed
