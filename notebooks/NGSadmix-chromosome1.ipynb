# %% [markdown]
# # NGSadmix Test only on chromosome BEIS0100001.1 (768643 SNPS) ##Plot admixture from NGSadmix

# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/ngsadmix")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
dir()
# Out:
#  [1] "assignCHROM1_2.filter"         "assignCHROM1_2.fopt.gz"
#  [3] "assignCHROM1_2.log"            "assignCHROM1_2.qopt"
#  [5] "assignCHROM1_2sorthand.txt"    "assignCHROM1_3.filter"
#  [7] "assignCHROM1_3.fopt.gz"        "assignCHROM1_3.log"
#  [9] "assignCHROM1_3.qopt"           "assignCHROM1_3sorthand.txt"
# [11] "assignCHROM1_4.filter"         "assignCHROM1_4.fopt.gz"
# [13] "assignCHROM1_4.log"            "assignCHROM1_4.qopt"
# [15] "assignCHROM1_4sorthand.txt"    "assignCHROM1_5.filter"
# [17] "assignCHROM1_5.fopt.gz"        "assignCHROM1_5.log"
# [19] "assignCHROM1_5.qopt"           "assignCHROM1_5sorthand.txt"
# [21] "assignCHROM1_6.filter"         "assignCHROM1_6.fopt.gz"
# [23] "assignCHROM1_6.log"            "assignCHROM1_6.qopt"
# [25] "assignCHROM1_6sorthand.txt"    "biallelic7chrom.recode.vcf.gz"
# [27] "popvarroa-mtdna.txt"           "R"

# %%
admix2<-t(as.matrix(read.table("assignCHROM1_2sorthand.txt")))
barplot(admix2, col=c("blue3", "red2"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix3 <-t(as.matrix(read.table("assignCHROM1_3sorthand.txt")))
barplot(admix3, col=c("blue3", "red2", "black"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix4 <-t(as.matrix(read.table("assignCHROM1_4sorthand.txt")))
barplot(admix4, col=c("black", "red2", "blue3", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix5 <-t(as.matrix(read.table("assignCHROM1_5sorthand.txt")))
barplot(admix5, col=c("black", "blue3", "red2", "cyan", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix6 <-t(as.matrix(read.table("assignCHROM1_6sorthand.txt")))
barplot(admix6, col=c("black", "lightpink", "blue3", "red2", "cyan", "white"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pdf(file = "NGSAdmixtest-chrom1-201117.pdf", height=30, width= 20)
par(mfrow=c(5,1)) 
barplot(admix2, col=c("blue3", "red2"),space=0,border= TRUE,xlab= "best like=-9167470.260341 after 104 iterations", ylab="admixture")
barplot(admix3, col=c("blue3", "red2", "black"),space=0,border=TRUE,xlab= "best like=-7852069.779054 after 121 iterations",ylab="admixture")
barplot(admix4, col=c("black", "red2", "blue3", "lightpink"),space=0,border=TRUE,xlab= "best like=-6077598.185511 after 155 iterations",ylab="admixture")
barplot(admix5, col=c("black", "blue3", "red2", "cyan", "lightpink"),space=0,border=TRUE,xlab= "best like=-5495617.801711 after 241 iterations",ylab="admixture")
barplot(admix6, col=c("black", "lightpink", "blue3", "red2", "cyan", "white"),space=0,border=TRUE,xlab= "best like=-4592905.284556 after 275 iterations",ylab="admixture")
dev.off()
# Out:
# png
#   2

# %%
dev.off()
# Out:
# null device
#           1
