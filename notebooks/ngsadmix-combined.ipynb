# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/ngsadmix/R")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
dir()
# Out:
# [1] "combined_2sorthand.txt" "combined_3sorthand.txt" "combined_4sorthand.txt"
# [4] "combined_5sorthand.txt" "combined_6sorthand.txt" "combined_7sorthand.txt"

# %%
admix2<-t(as.matrix(read.table("combined_2sorthand.txt")))
barplot(admix2, col=c("red2", "blue3"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix3 <-t(as.matrix(read.table("combined_3sorthand.txt")))
barplot(admix3, col=c("black", "red2", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix4 <-t(as.matrix(read.table("combined_4sorthand.txt")))
barplot(admix4, col=c("red2", "cyan", "black", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix5 <-t(as.matrix(read.table("combined_5sorthand.txt")))
barplot(admix5, col=c("red2", "cyan", "black", "blue3", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix6 <-t(as.matrix(read.table("combined_6sorthand.txt")))
barplot(admix6, col=c("red2", "white", "cyan", "black", "lightpink", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix7 <-t(as.matrix(read.table("combined_7sorthand.txt")))
barplot(admix7, col=c("blue3","red2", "black", "gray", "lightpink", "white", "cyan"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pdf(file = "NGSAdmixtest-combined-051217.pdf", height=30, width= 20)
par(mfrow=c(5,1)) 
barplot(admix2, col=c("red2", "blue3"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix3, col=c("black", "red2", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix4, col=c("red2", "cyan", "black", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix5, col=c("red2", "cyan", "black", "blue3", "lightpink"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix6, col=c("red2", "white", "cyan", "black", "lightpink", "blue3"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
barplot(admix7, col=c("blue3","red2", "black", "gray", "lightpink", "white", "cyan"),space=0,border=TRUE,xlab="Individuals",ylab="admixture")
dev.off()
# Out:
# png
#   2

# %%
dev.off()
# Out:
# null device
#           1
