# %%
##Setting the path for the packages
setwd("/work/MikheyevU/Maeva/varroa-jump/data/ngsadmix/R")
.libPaths("/home/m/maeva-techer/R/x86_64-redhat-linux-gnu-library/3.2")

# %%
dir()
# Out:
#  [1] "all44_2.txt"                        "all44_3.txt"
#  [3] "all44_4.txt"                        "all44_5.txt"
#  [5] "all44_6.txt"                        "all44_7.txt"
#  [7] "NGSAdmixtest-combined-14022018.pdf" "NGSAdmixtest-VDONLY-14022018.pdf"
#  [9] "vd_2.txt"                           "vd_3.txt"
# [11] "vd_4.txt"                           "vd_5.txt"
# [13] "vd_6.txt"                           "vd_7.txt"
# [15] "vj_2.txt"                           "vj_3.txt"
# [17] "vj_4.txt"                           "vj_5.txt"
# [19] "vj_6.txt"                           "vj_7.txt"

# %%
admix2<-t(as.matrix(read.table("vj_2.txt")))
barplot(admix2, col=c("blue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix3<-t(as.matrix(read.table("vj_3.txt")))
barplot(admix3, col=c("blue", "navyblue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix4<-t(as.matrix(read.table("vj_4.txt")))
barplot(admix4, col=c("paleturquoise", "blue", "navyblue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admix5<-t(as.matrix(read.table("vj_5.txt")))
barplot(admix5, col=c("paleturquoise", "cyan", "blue", "navyblue", "black"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pdf(file = "NGSAdmixtest-VJONLY-14022018.pdf", height=30, width= 20)
par(mfrow=c(6,1)) 
barplot(admix2, col=c("blue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix3, col=c("blue", "navyblue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix4, col=c("paleturquoise", "blue", "navyblue", "cyan"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
barplot(admix5, col=c("paleturquoise", "cyan", "blue", "navyblue", "black"),space=0,border= TRUE,xlab="Individuals",ylab="admixture")
dev.off()
# Out:
# png
#   2

# %%
dev.off()
# Out:
# null device
#           1
